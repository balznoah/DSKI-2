# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### S - Specific : Modellierung eines  Machine-Learning Modells zur Klassifikation von E-mails in die Labels "Spam" und "not Spam".
# #### M - Measurable( Accuracy und False-Positive Rate)
# #### A - Achievable : Umsetzbar mit Hilfe eines Machine-Learning Models zur binären Klassifikation (Python Libraries).
# #### R - Realistic :
# #### T - Time : Notebook bis zum 29.04.2026

# %%
df = pd.read_csv("email_spam.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0                          ?? the secrets to SUCCESS
# 1                    ?? You Earned 500 GCLoot Points
# 2                         ?? Your GitHub launch code
# 3  [The Virtual Reward Center] Re: ** Clarifications
# 4  10-1 MLB Expert Inside, Plus Everything You Ne...
#
#                                                 text      type
# 0  Hi James,\n\nHave you claim your complimentary...      spam
# 1  \nalt_text\nCongratulations, you just earned\n...  not spam
# 2  Here's your GitHub launch code, @Mortyj420!\n ...  not spam
# 3  Hello,\n \nThank you for contacting the Virtua...  not spam
# 4  Hey Prachanda Rawal,\n\nToday's newsletter is ...      spam

# %%
df.describe()
# Out:
#           title                                               text      type
# count        84                                                 84        84
# unique       78                                                 82         2
# top     English  Model Casting Call\nThank you for taking the t...  not spam
# freq          3                                                  2        58

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   title   84 non-null     object
#  1   text    84 non-null     object
#  2   type    84 non-null     object
#  3   email   84 non-null     string
#  4   tokens  84 non-null     object
# dtypes: object(4), string(1)
# memory usage: 3.4+ KB

# %%
import re

# %%
figure = plt.hist(df.type)
figure = plt.title("type")
plt.show()

# %%
df["tokens"] = df["text"].str.split()

# Alle Tokens aus allen Zeilen zu einer einzigen Liste zusammenführen
word_list = np.concatenate(df["tokens"].values)


word_counts = pd.Series(word_list).value_counts()
word_counts = word_counts.reset_index()
word_counts.columns = ["word", "count"]

# Häufigste Wörter:
word_counts.head()
# Out:
#    word  count
# 0    to    334
# 1   the    325
# 2   and    233
# 3  your    200
# 4   you    197

# %%
# Barchart Top 20 Wörter
top_n = 20
top_words = word_counts.head(top_n)

# Plot
plt.figure(figsize=(10, 6))
plt.bar(top_words["word"], top_words["count"])
plt.title(f"Top {top_n} häufigste Wörter")
plt.xlabel("Wort")
plt.ylabel("Anzahl")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
